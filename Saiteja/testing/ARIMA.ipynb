# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.9/site-packages (0.14.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (23.2)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# WARNING: You are using pip version 19.3.1; however, version 24.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, r2_score

# %%
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()
 
table_name = '"FACT_CUSTOMER_ORDERS"'
 
sf_df = my_session.sql("select * from {}".format(table_name))
df = sf_df.to_pandas()

# %%
data = df[['PRODUCT_ID','ORDER_DATE','ORDER_QTY']]

# %%
data['ORDER_DATE']=pd.to_datetime(data['ORDER_DATE'])

# %%
data_grouped = data.groupby(['PRODUCT_ID',data['ORDER_DATE'].dt.to_period('M')]).agg(Total_Order_Qty=('ORDER_QTY','sum')).reset_index()

# %%
data_grouped['ORDER_MONTH']=data_grouped['ORDER_DATE'].dt.to_timestamp()

# %%
data_grouped = data_grouped[['PRODUCT_ID','ORDER_MONTH','Total_Order_Qty']]

# %%
data_grouped = data_grouped.set_index('ORDER_MONTH')

# %%
# Group data by 'product_id'
PID_grouped_data = data_grouped.groupby('PRODUCT_ID')

# %%
# Initialize an empty DataFrame for forecast results
test_results = pd.DataFrame(columns=['PRODUCT_ID','ORDER_MONTH', 'test_forecast_orders','rse', 'rmse','r2_score'])

# %%
forecast_results = pd.DataFrame(columns=['PRODUCT_ID','ORDER_MONTH', 'forecast_order_qty'])

# %%
for product_id, group in PID_grouped_data:
    # Sort data by order date
    group.sort_index(inplace=True)

    print(f'{group}')
    
    # Split data into train and test sets (80% train, 20% test)
    train_size = int(0.8 * len(group))
    train_data, test_data = group.iloc[:train_size], group.iloc[train_size:]

    print(f'{train_data.index}')
    
    # Create SARIMAX model
    #model = SARIMAX(train_data['Total_Order_Qty'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))

    model = ARIMA(train_data['Total_Order_Qty'], order=(1, 1, 1))  # (p, d, q) parameters
    model_fit = model.fit()
    
    # Forecast the next period
    test_model = model_fit.get_forecast(steps=len(test_data))
    test_df = test_model.predicted_mean

    #print(f'test_df:{test_df.index}')
    
    # Calculate RMSE for order quantity
    #rmse_order_qty = np.sqrt(mean_squared_error(test_data['ORDER_QTY'], forecast_order_qty))
    
    # Evaluate the model
    rse = np.sqrt(((test_df - test_data) ** 2).sum().sum() / (test_data.shape[0] * test_data.shape[1] - len(model_fit.params)))
    rmse = np.sqrt(mean_squared_error(test_data['Total_Order_Qty'], test_df))
    r2 = r2_score(test_data['Total_Order_Qty'], test_df)

    
    date_list = test_df.index.to_list()
    

    
    #print(f"Order_date: {date_list}")    
    new_row = {
        'PRODUCT_ID': product_id,
        'ORDER_MONTH': date_list,
        'test_forecast_orders': test_df,
        'rse': rse,
        'rmse': rmse,
        'r2_score': r2
    }
    
    df_new = pd.DataFrame(new_row)

    df_new.set_index('ORDER_MONTH')
    
    test_results=pd.concat([test_results,df_new],ignore_index=True)
    # Forecast future values
    forecast = model_fit.get_forecast(steps=25)#, steps=n_forecast)
    forecast_df = forecast.predicted_mean
    print(f'{forecast_df.index}')
    date_list2= forecast_df.index.to_list()
    
    new_row2 = {
        'PRODUCT_ID': product_id,
        'ORDER_MONTH': date_list2,
        'forecast_order_qty': forecast_df,
    }
    
    df_new2 = pd.DataFrame(new_row2)
    
    forecast_results=pd.concat([forecast_results,df_new2],ignore_index=True)
# Out:
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_001           148400
# 2019-02-01   Product_001           146650
# 2019-03-01   Product_001           133150
# 2019-04-01   Product_001           153600
# 2019-05-01   Product_001           154650
# ...                  ...              ...
# 2024-04-01   Product_001           128300
# 2024-05-01   Product_001           115350
# 2024-06-01   Product_001           144950
# 2024-07-01   Product_001           155700
# 2024-08-01   Product_001           113300
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_002            64750
# 2019-02-01   Product_002            83350
# 2019-03-01   Product_002            77650
# 2019-04-01   Product_002            76300
# 2019-05-01   Product_002            89400
# ...                  ...              ...
# 2024-04-01   Product_002            79200
# 2024-05-01   Product_002            54050
# 2024-06-01   Product_002            82200
# 2024-07-01   Product_002            76600
# 2024-08-01   Product_002            71350
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_003            46250
# 2019-02-01   Product_003            48150
# 2019-03-01   Product_003            45900
# 2019-04-01   Product_003            40750
# 2019-05-01   Product_003            53150
# ...                  ...              ...
# 2024-04-01   Product_003            43500
# 2024-05-01   Product_003            44850
# 2024-06-01   Product_003            53900
# 2024-07-01   Product_003            46050
# 2024-08-01   Product_003            34700
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_004            38950
# 2019-02-01   Product_004            48900
# 2019-03-01   Product_004            58350
# 2019-04-01   Product_004            55300
# 2019-05-01   Product_004            51500
# ...                  ...              ...
# 2024-04-01   Product_004            65400
# 2024-05-01   Product_004            41000
# 2024-06-01   Product_004            44200
# 2024-07-01   Product_004            52800
# 2024-08-01   Product_004            33900
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_007            29050
# 2019-02-01   Product_007            30650
# 2019-03-01   Product_007            29850
# 2019-04-01   Product_007            35250
# 2019-05-01   Product_007            45850
# ...                  ...              ...
# 2024-04-01   Product_007            38400
# 2024-05-01   Product_007            32350
# 2024-06-01   Product_007            40600
# 2024-07-01   Product_007            30600
# 2024-08-01   Product_007            27600
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_010            75950
# 2019-02-01   Product_010            85600
# 2019-03-01   Product_010            81300
# 2019-04-01   Product_010            87300
# 2019-05-01   Product_010            86900
# ...                  ...              ...
# 2024-04-01   Product_010            82000
# 2024-05-01   Product_010            59450
# 2024-06-01   Product_010            78500
# 2024-07-01   Product_010            99000
# 2024-08-01   Product_010            67850
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_015            77050
# 2019-02-01   Product_015            68750
# 2019-03-01   Product_015            51050
# 2019-04-01   Product_015            64000
# 2019-05-01   Product_015            65600
# ...                  ...              ...
# 2024-04-01   Product_015            56850
# 2024-05-01   Product_015            51950
# 2024-06-01   Product_015            67000
# 2024-07-01   Product_015            86800
# 2024-08-01   Product_015            44800
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_016            82400
# 2019-02-01   Product_016            91850
# 2019-03-01   Product_016            85100
# 2019-04-01   Product_016           102550
# 2019-05-01   Product_016            84400
# ...                  ...              ...
# 2024-04-01   Product_016            92000
# 2024-05-01   Product_016            76850
# 2024-06-01   Product_016            89900
# 2024-07-01   Product_016           114750
# 2024-08-01   Product_016            64650
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_019            72150
# 2019-02-01   Product_019            92150
# 2019-03-01   Product_019           100500
# 2019-04-01   Product_019            83650
# 2019-05-01   Product_019            86900
# ...                  ...              ...
# 2024-04-01   Product_019            82450
# 2024-05-01   Product_019            56550
# 2024-06-01   Product_019            76300
# 2024-07-01   Product_019            87150
# 2024-08-01   Product_019            60500
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_023            74900
# 2019-02-01   Product_023            84150
# 2019-03-01   Product_023           101900
# 2019-04-01   Product_023            82300
# 2019-05-01   Product_023            86150
# ...                  ...              ...
# 2024-04-01   Product_023            88150
# 2024-05-01   Product_023            65950
# 2024-06-01   Product_023            86400
# 2024-07-01   Product_023            98350
# 2024-08-01   Product_023            70650
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_047            25550
# 2019-02-01   Product_047            31150
# 2019-03-01   Product_047            33800
# 2019-04-01   Product_047            27900
# 2019-05-01   Product_047            24200
# ...                  ...              ...
# 2024-04-01   Product_047            32150
# 2024-05-01   Product_047            25750
# 2024-06-01   Product_047            26950
# 2024-07-01   Product_047            31500
# 2024-08-01   Product_047            27350
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_057            36000
# 2019-02-01   Product_057            37650
# 2019-03-01   Product_057            45950
# 2019-04-01   Product_057            36650
# 2019-05-01   Product_057            39200
# ...                  ...              ...
# 2024-04-01   Product_057            35300
# 2024-05-01   Product_057            26000
# 2024-06-01   Product_057            41800
# 2024-07-01   Product_057            42450
# 2024-08-01   Product_057            24650
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_059            24250
# 2019-02-01   Product_059            37350
# 2019-03-01   Product_059            27450
# 2019-04-01   Product_059            26750
# 2019-05-01   Product_059            23850
# ...                  ...              ...
# 2024-04-01   Product_059            28450
# 2024-05-01   Product_059            24750
# 2024-06-01   Product_059            28800
# 2024-07-01   Product_059            34550
# 2024-08-01   Product_059            25800
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_060            25850
# 2019-02-01   Product_060            25800
# 2019-03-01   Product_060            30800
# 2019-04-01   Product_060            27700
# 2019-05-01   Product_060            19600
# ...                  ...              ...
# 2024-04-01   Product_060            25700
# 2024-05-01   Product_060            26550
# 2024-06-01   Product_060            26050
# 2024-07-01   Product_060            27100
# 2024-08-01   Product_060            23450
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_061            21800
# 2019-02-01   Product_061            32900
# 2019-03-01   Product_061            30850
# 2019-04-01   Product_061            23700
# 2019-05-01   Product_061            30450
# ...                  ...              ...
# 2024-04-01   Product_061            30500
# 2024-05-01   Product_061            29500
# 2024-06-01   Product_061            39650
# 2024-07-01   Product_061            33450
# 2024-08-01   Product_061            25150
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_063            27950
# 2019-02-01   Product_063            27950
# 2019-03-01   Product_063            34650
# 2019-04-01   Product_063            27700
# 2019-05-01   Product_063            33400
# ...                  ...              ...
# 2024-04-01   Product_063            23550
# 2024-05-01   Product_063            30050
# 2024-06-01   Product_063            28050
# 2024-07-01   Product_063            35350
# 2024-08-01   Product_063            26700
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_065            26000
# 2019-02-01   Product_065            31400
# 2019-03-01   Product_065            25850
# 2019-04-01   Product_065            25300
# 2019-05-01   Product_065            19700
# ...                  ...              ...
# 2024-04-01   Product_065            22650
# 2024-05-01   Product_065            23300
# 2024-06-01   Product_065            31650
# 2024-07-01   Product_065            36600
# 2024-08-01   Product_065            25750
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_066            27600
# 2019-02-01   Product_066            29700
# 2019-03-01   Product_066            35400
# 2019-04-01   Product_066            28100
# 2019-05-01   Product_066            35100
# ...                  ...              ...
# 2024-04-01   Product_066            35800
# 2024-05-01   Product_066            35100
# 2024-06-01   Product_066            36400
# 2024-07-01   Product_066            39700
# 2024-08-01   Product_066            25000
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_067            34300
# 2019-02-01   Product_067            42700
# 2019-03-01   Product_067            50500
# 2019-04-01   Product_067            35200
# 2019-05-01   Product_067            55300
# ...                  ...              ...
# 2024-04-01   Product_067            43800
# 2024-05-01   Product_067            27950
# 2024-06-01   Product_067            63000
# 2024-07-01   Product_067            53300
# 2024-08-01   Product_067            38150
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_069            21500
# 2019-02-01   Product_069            29450
# 2019-03-01   Product_069            30050
# 2019-04-01   Product_069            26300
# 2019-05-01   Product_069            31650
# ...                  ...              ...
# 2024-04-01   Product_069            29200
# 2024-05-01   Product_069            21150
# 2024-06-01   Product_069            32150
# 2024-07-01   Product_069            43450
# 2024-08-01   Product_069            30950
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_070            24300
# 2019-02-01   Product_070            27000
# 2019-03-01   Product_070            32700
# 2019-04-01   Product_070            33000
# 2019-05-01   Product_070            34450
# ...                  ...              ...
# 2024-04-01   Product_070            33300
# 2024-05-01   Product_070            22100
# 2024-06-01   Product_070            23100
# 2024-07-01   Product_070            36500
# 2024-08-01   Product_070            27950
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_071            24600
# 2019-02-01   Product_071            32500
# 2019-03-01   Product_071            34900
# 2019-04-01   Product_071            24800
# 2019-05-01   Product_071            29450
# ...                  ...              ...
# 2024-04-01   Product_071            27000
# 2024-05-01   Product_071            24850
# 2024-06-01   Product_071            25850
# 2024-07-01   Product_071            30100
# 2024-08-01   Product_071            24150
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_072            27750
# 2019-02-01   Product_072            25900
# 2019-03-01   Product_072            32950
# 2019-04-01   Product_072            37800
# 2019-05-01   Product_072            28700
# ...                  ...              ...
# 2024-04-01   Product_072            30200
# 2024-05-01   Product_072            23150
# 2024-06-01   Product_072            27950
# 2024-07-01   Product_072            29950
# 2024-08-01   Product_072            27700
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
# ...
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_093            28350
# 2019-02-01   Product_093            35200
# 2019-03-01   Product_093            20450
# 2019-04-01   Product_093            35450
# 2019-05-01   Product_093            40150
# ...                  ...              ...
# 2024-04-01   Product_093            32000
# 2024-05-01   Product_093            34050
# 2024-06-01   Product_093            22500
# 2024-07-01   Product_093            25050
# 2024-08-01   Product_093            27450
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_094            34600
# 2019-02-01   Product_094            40700
# 2019-03-01   Product_094            47200
# 2019-04-01   Product_094            41650
# 2019-05-01   Product_094            39700
# ...                  ...              ...
# 2024-04-01   Product_094            40750
# 2024-05-01   Product_094            35900
# 2024-06-01   Product_094            43100
# 2024-07-01   Product_094            49250
# 2024-08-01   Product_094            31550
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_095            31000
# 2019-02-01   Product_095            40600
# 2019-03-01   Product_095            34400
# 2019-04-01   Product_095            33150
# 2019-05-01   Product_095            33800
# ...                  ...              ...
# 2024-04-01   Product_095            40100
# 2024-05-01   Product_095            28400
# 2024-06-01   Product_095            36650
# 2024-07-01   Product_095            42300
# 2024-08-01   Product_095            34950
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_096            32000
# 2019-02-01   Product_096            25500
# 2019-03-01   Product_096            29500
# 2019-04-01   Product_096            25900
# 2019-05-01   Product_096            24950
# ...                  ...              ...
# 2024-04-01   Product_096            30200
# 2024-05-01   Product_096            26250
# 2024-06-01   Product_096            23300
# 2024-07-01   Product_096            34950
# 2024-08-01   Product_096            27600
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_097            28750
# 2019-02-01   Product_097            29450
# 2019-03-01   Product_097            35550
# 2019-04-01   Product_097            24650
# 2019-05-01   Product_097            32800
# ...                  ...              ...
# 2024-04-01   Product_097            24900
# 2024-05-01   Product_097            18200
# 2024-06-01   Product_097            29550
# 2024-07-01   Product_097            38000
# 2024-08-01   Product_097            21850
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_098            21950
# 2019-02-01   Product_098            24400
# 2019-03-01   Product_098            31100
# 2019-04-01   Product_098            32900
# 2019-05-01   Product_098            27500
# ...                  ...              ...
# 2024-04-01   Product_098            28950
# 2024-05-01   Product_098            32950
# 2024-06-01   Product_098            34250
# 2024-07-01   Product_098            27750
# 2024-08-01   Product_098            21650
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')
#               PRODUCT_ID  Total_Order_Qty
# ORDER_MONTH
# 2019-01-01   Product_100            25050
# 2019-02-01   Product_100            33600
# 2019-03-01   Product_100            33550
# 2019-04-01   Product_100            21750
# 2019-05-01   Product_100            22100
# ...                  ...              ...
# 2024-04-01   Product_100            30200
# 2024-05-01   Product_100            27850
# 2024-06-01   Product_100            33200
# 2024-07-01   Product_100            33300
# 2024-08-01   Product_100            30700
#
# [68 rows x 2 columns]
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01'],
#               dtype='datetime64[ns]', name='ORDER_MONTH', freq=None)
# DatetimeIndex(['2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01', '2024-06-01',
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01',
#                '2025-07-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
test_results
# Out:
#       PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0    Product_001  2023-07-01         119922.915547  0.0  17133.679442
# 1    Product_001  2023-08-01         119518.208708  0.0  17133.679442
# 2    Product_001  2023-09-01         119441.207710  0.0  17133.679442
# 3    Product_001  2023-10-01         119426.557220  0.0  17133.679442
# 4    Product_001  2023-11-01         119423.769764  0.0  17133.679442
# ..           ...         ...                   ...  ...           ...
# 611  Product_100  2024-04-01          25942.448715  0.0   5520.954867
# 612  Product_100  2024-05-01          25942.448717  0.0   5520.954867
# 613  Product_100  2024-06-01          25942.448717  0.0   5520.954867
# 614  Product_100  2024-07-01          25942.448717  0.0   5520.954867
# 615  Product_100  2024-08-01          25942.448717  0.0   5520.954867
#
#      r2_score
# 0   -0.256974
# 1   -0.256974
# 2   -0.256974
# 3   -0.256974
# 4   -0.256974
# ..        ...
# 611 -0.517181
# 612 -0.517181
# 613 -0.517181
# 614 -0.517181
# 615 -0.517181
#
# [616 rows x 6 columns]
