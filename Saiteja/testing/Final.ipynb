# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.9/site-packages (0.14.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (2.2.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (23.2)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# WARNING: You are using pip version 19.3.1; however, version 24.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, r2_score

# %%
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()
 
table_name = '"FACT_CUSTOMER_ORDERS"'
 
sf_df = my_session.sql("select * from {}".format(table_name))
df = sf_df.to_pandas()

# %%
data = df[['PRODUCT_ID','ORDER_DATE','ORDER_QTY']]

# %%
data['ORDER_DATE']=pd.to_datetime(data['ORDER_DATE'])

# %%
data_grouped = data.groupby(['PRODUCT_ID',data['ORDER_DATE'].dt.to_period('M')]).agg(Total_Order_Qty=('ORDER_QTY','sum')).reset_index()

# %%
data_grouped['ORDER_MONTH']=data_grouped['ORDER_DATE'].dt.to_timestamp()

# %%
data_grouped = data_grouped[['PRODUCT_ID','ORDER_MONTH','Total_Order_Qty']]

# %%
data_grouped
# Out:
#        PRODUCT_ID ORDER_MONTH  Total_Order_Qty
# 0     Product_001  2019-01-01           148400
# 1     Product_001  2019-02-01           146650
# 2     Product_001  2019-03-01           133150
# 3     Product_001  2019-04-01           153600
# 4     Product_001  2019-05-01           154650
# ...           ...         ...              ...
# 2987  Product_100  2024-04-01            30200
# 2988  Product_100  2024-05-01            27850
# 2989  Product_100  2024-06-01            33200
# 2990  Product_100  2024-07-01            33300
# 2991  Product_100  2024-08-01            30700
#
# [2992 rows x 3 columns]

# %%
data_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2992 entries, 0 to 2991
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT_ID       2992 non-null   object
#  1   ORDER_MONTH      2992 non-null   datetime64[ns]
#  2   Total_Order_Qty  2992 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 70.2+ KB

# %%
data_grouped = data_grouped.set_index('ORDER_MONTH')

# %%
data_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2992 entries, 2019-01-01 to 2024-08-01
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT_ID       2992 non-null   object
#  1   Total_Order_Qty  2992 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 70.1+ KB

# %%
# Group data by 'product_id'
PID_grouped_data = data_grouped.groupby('PRODUCT_ID')

# %%
# Initialize an empty DataFrame for forecast results
test_results = pd.DataFrame(columns=['PRODUCT_ID','ORDER_MONTH', 'test_forecast_orders','rse', 'rmse','r2_score'])

# %%
# Initialize an empty DataFrame for forecast results
forecast_results = pd.DataFrame(columns=['PRODUCT_ID','ORDER_MONTH', 'forecast_order_qty'])

# %%
print(PID_grouped_data)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f0a2bc38b80>

# %%
for product_id, group in PID_grouped_data:
    # Sort data by order date
    group.sort_index(inplace=True)
    
    # Split data into train and test sets (80% train, 20% test)
    train_size = int(0.8 * len(group))
    train_data, test_data = group.iloc[:train_size], group.iloc[train_size:]

    
    
    # Create SARIMAX model
    model = SARIMAX(train_data['Total_Order_Qty'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
    model_fit = model.fit(disp=False)
    
    # Forecast the next period
    test_model = model_fit.get_forecast(steps=len(test_data))
    test_df = test_model.predicted_mean

    #print(f'test_df:{test_df.index}')
    
    # Calculate RMSE for order quantity
    #rmse_order_qty = np.sqrt(mean_squared_error(test_data['ORDER_QTY'], forecast_order_qty))
    
    # Evaluate the model
    rse = np.sqrt(((test_df - test_data) ** 2).sum().sum() / (test_data.shape[0] * test_data.shape[1] - len(model_fit.params)))
    rmse = np.sqrt(mean_squared_error(test_data['Total_Order_Qty'], test_df))
    r2 = r2_score(test_data['Total_Order_Qty'], test_df)

    
    date_list = test_df.index.to_list()
    

    
    #print(f"Order_date: {date_list}")    
    new_row = {
        'product_id': product_id,
        'order_date': date_list,
        'test_forecast_orders': test_df,
        'rse': rse,
        'rmse': rmse,
        'r2_score': r2
    }
    
    df_new = pd.DataFrame(new_row)

    df_new.index
    
    test_results=pd.concat([test_results,df_new],ignore_index=True)
    print(f'{test_results}')
    # Forecast future values
    forecast = model_fit.get_forecast(steps=25)#, steps=n_forecast)
    forecast_df = forecast.predicted_mean
    
    date_list2= forecast_df.index.to_list()
    
    new_row2 = {
        'product_id': product_id,
        'order_date': date_list2,
        'forecast_order_qty': forecast_df,
    }
    
    df_new2 = pd.DataFrame(new_row2)
    
    forecast_results=pd.concat([forecast_results,df_new2],ignore_index=True)
# Out:
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6169        NaN         NaN         122617.484315  0.0  15697.565379
# 6170        NaN         NaN         113678.212178  0.0  15697.565379
# 6171        NaN         NaN         122553.505870  0.0  15697.565379
# 6172        NaN         NaN         123281.759280  0.0  15697.565379
# 6173        NaN         NaN         106051.738107  0.0  15697.565379
#
#       r2_score   product_id order_date
# 0     -0.05509  Product_001 2023-07-01
# 1     -0.05509  Product_001 2023-08-01
# 2     -0.05509  Product_001 2023-09-01
# 3     -0.05509  Product_001 2023-10-01
# 4     -0.05509  Product_001 2023-11-01
# ...        ...          ...        ...
# 6169  -0.05509  Product_001 2024-04-01
# 6170  -0.05509  Product_001 2024-05-01
# 6171  -0.05509  Product_001 2024-06-01
# 6172  -0.05509  Product_001 2024-07-01
# 6173  -0.05509  Product_001 2024-08-01
#
# [6174 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6183        NaN         NaN          75494.743748  0.0   8635.840218
# 6184        NaN         NaN          72261.376450  0.0   8635.840218
# 6185        NaN         NaN          74580.228566  0.0   8635.840218
# 6186        NaN         NaN          80385.385932  0.0   8635.840218
# 6187        NaN         NaN          66463.441620  0.0   8635.840218
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6183  0.310731  Product_002 2024-04-01
# 6184  0.310731  Product_002 2024-05-01
# 6185  0.310731  Product_002 2024-06-01
# 6186  0.310731  Product_002 2024-07-01
# 6187  0.310731  Product_002 2024-08-01
#
# [6188 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6197        NaN         NaN          45165.209498  0.0   5657.870658
# 6198        NaN         NaN          38419.016735  0.0   5657.870658
# 6199        NaN         NaN          46741.758783  0.0   5657.870658
# 6200        NaN         NaN          46423.732650  0.0   5657.870658
# 6201        NaN         NaN          33312.273972  0.0   5657.870658
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6197 -0.091632  Product_003 2024-04-01
# 6198 -0.091632  Product_003 2024-05-01
# 6199 -0.091632  Product_003 2024-06-01
# 6200 -0.091632  Product_003 2024-07-01
# 6201 -0.091632  Product_003 2024-08-01
#
# [6202 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6211        NaN         NaN          38299.708017  0.0  13460.088442
# 6212        NaN         NaN          27092.893751  0.0  13460.088442
# 6213        NaN         NaN          34646.233426  0.0  13460.088442
# 6214        NaN         NaN          35336.596995  0.0  13460.088442
# 6215        NaN         NaN          23860.547153  0.0  13460.088442
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6211 -1.265111  Product_004 2024-04-01
# 6212 -1.265111  Product_004 2024-05-01
# 6213 -1.265111  Product_004 2024-06-01
# 6214 -1.265111  Product_004 2024-07-01
# 6215 -1.265111  Product_004 2024-08-01
#
# [6216 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6225        NaN         NaN          28302.582061  0.0   6202.608452
# 6226        NaN         NaN          25863.613936  0.0   6202.608452
# 6227        NaN         NaN          27386.416545  0.0   6202.608452
# 6228        NaN         NaN          30146.200018  0.0   6202.608452
# 6229        NaN         NaN          21279.194555  0.0   6202.608452
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6225 -0.253285  Product_007 2024-04-01
# 6226 -0.253285  Product_007 2024-05-01
# 6227 -0.253285  Product_007 2024-06-01
# 6228 -0.253285  Product_007 2024-07-01
# 6229 -0.253285  Product_007 2024-08-01
#
# [6230 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6239        NaN         NaN          67616.868525  0.0   9073.301156
# 6240        NaN         NaN          70619.511905  0.0   9073.301156
# 6241        NaN         NaN          76633.016724  0.0   9073.301156
# 6242        NaN         NaN          80224.282385  0.0   9073.301156
# 6243        NaN         NaN          68531.350195  0.0   9073.301156
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6239  0.408808  Product_010 2024-04-01
# 6240  0.408808  Product_010 2024-05-01
# 6241  0.408808  Product_010 2024-06-01
# 6242  0.408808  Product_010 2024-07-01
# 6243  0.408808  Product_010 2024-08-01
#
# [6244 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6253        NaN         NaN          59332.550685  0.0  10852.960481
# 6254        NaN         NaN          49969.054568  0.0  10852.960481
# 6255        NaN         NaN          55831.281557  0.0  10852.960481
# 6256        NaN         NaN          60161.815750  0.0  10852.960481
# 6257        NaN         NaN          50826.053592  0.0  10852.960481
#
#       r2_score   product_id order_date
# 0     -0.05509  Product_001 2023-07-01
# 1     -0.05509  Product_001 2023-08-01
# 2     -0.05509  Product_001 2023-09-01
# 3     -0.05509  Product_001 2023-10-01
# 4     -0.05509  Product_001 2023-11-01
# ...        ...          ...        ...
# 6253   0.12231  Product_015 2024-04-01
# 6254   0.12231  Product_015 2024-05-01
# 6255   0.12231  Product_015 2024-06-01
# 6256   0.12231  Product_015 2024-07-01
# 6257   0.12231  Product_015 2024-08-01
#
# [6258 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6267        NaN         NaN          69941.311748  0.0  16038.934960
# 6268        NaN         NaN          55299.432746  0.0  16038.934960
# 6269        NaN         NaN          70425.084413  0.0  16038.934960
# 6270        NaN         NaN          92007.354380  0.0  16038.934960
# 6271        NaN         NaN          51602.838647  0.0  16038.934960
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6267 -0.760735  Product_016 2024-04-01
# 6268 -0.760735  Product_016 2024-05-01
# 6269 -0.760735  Product_016 2024-06-01
# 6270 -0.760735  Product_016 2024-07-01
# 6271 -0.760735  Product_016 2024-08-01
#
# [6272 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6281        NaN         NaN          62338.997883  0.0  17672.144854
# 6282        NaN         NaN          48737.834732  0.0  17672.144854
# 6283        NaN         NaN          56994.220102  0.0  17672.144854
# 6284        NaN         NaN          62370.420977  0.0  17672.144854
# 6285        NaN         NaN          50110.799515  0.0  17672.144854
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6281 -0.094872  Product_019 2024-04-01
# 6282 -0.094872  Product_019 2024-05-01
# 6283 -0.094872  Product_019 2024-06-01
# 6284 -0.094872  Product_019 2024-07-01
# 6285 -0.094872  Product_019 2024-08-01
#
# [6286 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6295        NaN         NaN          77388.256152  0.0  12735.624648
# 6296        NaN         NaN          70875.393050  0.0  12735.624648
# 6297        NaN         NaN          74337.667231  0.0  12735.624648
# 6298        NaN         NaN          88385.921461  0.0  12735.624648
# 6299        NaN         NaN          62819.558952  0.0  12735.624648
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6295 -0.851232  Product_023 2024-04-01
# 6296 -0.851232  Product_023 2024-05-01
# 6297 -0.851232  Product_023 2024-06-01
# 6298 -0.851232  Product_023 2024-07-01
# 6299 -0.851232  Product_023 2024-08-01
#
# [6300 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6309        NaN         NaN          30148.967578  0.0   4622.020383
# 6310        NaN         NaN          28974.387489  0.0   4622.020383
# 6311        NaN         NaN          31805.749489  0.0   4622.020383
# 6312        NaN         NaN          32479.236717  0.0   4622.020383
# 6313        NaN         NaN          31885.989699  0.0   4622.020383
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6309 -0.701711  Product_047 2024-04-01
# 6310 -0.701711  Product_047 2024-05-01
# 6311 -0.701711  Product_047 2024-06-01
# 6312 -0.701711  Product_047 2024-07-01
# 6313 -0.701711  Product_047 2024-08-01
#
# [6314 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6323        NaN         NaN          30974.105892  0.0   7432.016283
# 6324        NaN         NaN          28845.391536  0.0   7432.016283
# 6325        NaN         NaN          26624.316923  0.0   7432.016283
# 6326        NaN         NaN          35919.812104  0.0   7432.016283
# 6327        NaN         NaN          22595.690089  0.0   7432.016283
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6323 -0.810661  Product_057 2024-04-01
# 6324 -0.810661  Product_057 2024-05-01
# 6325 -0.810661  Product_057 2024-06-01
# 6326 -0.810661  Product_057 2024-07-01
# 6327 -0.810661  Product_057 2024-08-01
#
# [6328 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6337        NaN         NaN          23213.656378  0.0   7412.917842
# 6338        NaN         NaN          18234.460095  0.0   7412.917842
# 6339        NaN         NaN          23769.908730  0.0   7412.917842
# 6340        NaN         NaN          22803.213106  0.0   7412.917842
# 6341        NaN         NaN          18836.363660  0.0   7412.917842
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6337 -2.700831  Product_059 2024-04-01
# 6338 -2.700831  Product_059 2024-05-01
# 6339 -2.700831  Product_059 2024-06-01
# 6340 -2.700831  Product_059 2024-07-01
# 6341 -2.700831  Product_059 2024-08-01
#
# [6342 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6351        NaN         NaN          23840.442885  0.0   6524.867764
# 6352        NaN         NaN          23433.587357  0.0   6524.867764
# 6353        NaN         NaN          19664.068906  0.0   6524.867764
# 6354        NaN         NaN          27040.606109  0.0   6524.867764
# 6355        NaN         NaN          15019.875066  0.0   6524.867764
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6351 -4.394536  Product_060 2024-04-01
# 6352 -4.394536  Product_060 2024-05-01
# 6353 -4.394536  Product_060 2024-06-01
# 6354 -4.394536  Product_060 2024-07-01
# 6355 -4.394536  Product_060 2024-08-01
#
# [6356 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6365        NaN         NaN          26170.533168  0.0   7061.772430
# 6366        NaN         NaN          19578.489618  0.0   7061.772430
# 6367        NaN         NaN          24468.736140  0.0   7061.772430
# 6368        NaN         NaN          28508.266104  0.0   7061.772430
# 6369        NaN         NaN          23323.942050  0.0   7061.772430
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6365 -1.219454  Product_061 2024-04-01
# 6366 -1.219454  Product_061 2024-05-01
# 6367 -1.219454  Product_061 2024-06-01
# 6368 -1.219454  Product_061 2024-07-01
# 6369 -1.219454  Product_061 2024-08-01
#
# [6370 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6379        NaN         NaN          29856.882639  0.0   4053.774242
# 6380        NaN         NaN          25637.938572  0.0   4053.774242
# 6381        NaN         NaN          29316.362996  0.0   4053.774242
# 6382        NaN         NaN          33765.459446  0.0   4053.774242
# 6383        NaN         NaN          27422.142800  0.0   4053.774242
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6379 -0.052597  Product_063 2024-04-01
# 6380 -0.052597  Product_063 2024-05-01
# 6381 -0.052597  Product_063 2024-06-01
# 6382 -0.052597  Product_063 2024-07-01
# 6383 -0.052597  Product_063 2024-08-01
#
# [6384 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6393        NaN         NaN          22942.578015  0.0   8168.895607
# 6394        NaN         NaN          24917.664952  0.0   8168.895607
# 6395        NaN         NaN          17108.965859  0.0   8168.895607
# 6396        NaN         NaN          23820.748878  0.0   8168.895607
# 6397        NaN         NaN          18080.374139  0.0   8168.895607
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6393 -2.501842  Product_065 2024-04-01
# 6394 -2.501842  Product_065 2024-05-01
# 6395 -2.501842  Product_065 2024-06-01
# 6396 -2.501842  Product_065 2024-07-01
# 6397 -2.501842  Product_065 2024-08-01
#
# [6398 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6407        NaN         NaN          24563.753449  0.0   6472.896695
# 6408        NaN         NaN          24355.027334  0.0   6472.896695
# 6409        NaN         NaN          25214.689172  0.0   6472.896695
# 6410        NaN         NaN          30851.462446  0.0   6472.896695
# 6411        NaN         NaN          24053.034894  0.0   6472.896695
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6407 -0.144769  Product_066 2024-04-01
# 6408 -0.144769  Product_066 2024-05-01
# 6409 -0.144769  Product_066 2024-06-01
# 6410 -0.144769  Product_066 2024-07-01
# 6411 -0.144769  Product_066 2024-08-01
#
# [6412 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6421        NaN         NaN          36851.500565  0.0  10545.127369
# 6422        NaN         NaN          33010.788045  0.0  10545.127369
# 6423        NaN         NaN          34915.285118  0.0  10545.127369
# 6424        NaN         NaN          37652.379685  0.0  10545.127369
# 6425        NaN         NaN          36589.299369  0.0  10545.127369
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6421  0.032173  Product_067 2024-04-01
# 6422  0.032173  Product_067 2024-05-01
# 6423  0.032173  Product_067 2024-06-01
# 6424  0.032173  Product_067 2024-07-01
# 6425  0.032173  Product_067 2024-08-01
#
# [6426 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6435        NaN         NaN          29437.454500  0.0   5610.566971
# 6436        NaN         NaN          30697.478345  0.0   5610.566971
# 6437        NaN         NaN          29577.085471  0.0   5610.566971
# 6438        NaN         NaN          33376.595708  0.0   5610.566971
# 6439        NaN         NaN          28775.390962  0.0   5610.566971
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6435  0.232644  Product_069 2024-04-01
# 6436  0.232644  Product_069 2024-05-01
# 6437  0.232644  Product_069 2024-06-01
# 6438  0.232644  Product_069 2024-07-01
# 6439  0.232644  Product_069 2024-08-01
#
# [6440 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6449        NaN         NaN          30442.503451  0.0   5993.129617
# 6450        NaN         NaN          27831.833527  0.0   5993.129617
# 6451        NaN         NaN          30464.590240  0.0   5993.129617
# 6452        NaN         NaN          31236.055974  0.0   5993.129617
# 6453        NaN         NaN          25857.048518  0.0   5993.129617
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6449 -0.246368  Product_070 2024-04-01
# 6450 -0.246368  Product_070 2024-05-01
# 6451 -0.246368  Product_070 2024-06-01
# 6452 -0.246368  Product_070 2024-07-01
# 6453 -0.246368  Product_070 2024-08-01
#
# [6454 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6463        NaN         NaN          24429.415109  0.0   4902.444749
# 6464        NaN         NaN          25973.817542  0.0   4902.444749
# 6465        NaN         NaN          26646.414262  0.0   4902.444749
# 6466        NaN         NaN          31409.318677  0.0   4902.444749
# 6467        NaN         NaN          24753.453709  0.0   4902.444749
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6463 -0.224384  Product_071 2024-04-01
# 6464 -0.224384  Product_071 2024-05-01
# 6465 -0.224384  Product_071 2024-06-01
# 6466 -0.224384  Product_071 2024-07-01
# 6467 -0.224384  Product_071 2024-08-01
#
# [6468 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6477        NaN         NaN          24406.780536  0.0   5578.441376
# 6478        NaN         NaN          21140.299073  0.0   5578.441376
# 6479        NaN         NaN          23620.576735  0.0   5578.441376
# 6480        NaN         NaN          23859.969664  0.0   5578.441376
# 6481        NaN         NaN          22006.746037  0.0   5578.441376
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6477 -0.575654  Product_072 2024-04-01
# 6478 -0.575654  Product_072 2024-05-01
# 6479 -0.575654  Product_072 2024-06-01
# 6480 -0.575654  Product_072 2024-07-01
# 6481 -0.575654  Product_072 2024-08-01
#
# [6482 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6491        NaN         NaN          22815.251789  0.0   5908.105993
# 6492        NaN         NaN          27145.884725  0.0   5908.105993
# 6493        NaN         NaN          28976.882620  0.0   5908.105993
# 6494        NaN         NaN          34005.037620  0.0   5908.105993
# 6495        NaN         NaN          26562.068904  0.0   5908.105993
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6491 -0.621452  Product_074 2024-04-01
# 6492 -0.621452  Product_074 2024-05-01
# 6493 -0.621452  Product_074 2024-06-01
# 6494 -0.621452  Product_074 2024-07-01
# 6495 -0.621452  Product_074 2024-08-01
#
# [6496 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6505        NaN         NaN          17425.810381  0.0   8119.024007
# 6506        NaN         NaN          18550.334978  0.0   8119.024007
# 6507        NaN         NaN          21331.637485  0.0   8119.024007
# 6508        NaN         NaN          24315.347954  0.0   8119.024007
# 6509        NaN         NaN          13515.551197  0.0   8119.024007
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6505 -1.409959  Product_075 2024-04-01
# 6506 -1.409959  Product_075 2024-05-01
# 6507 -1.409959  Product_075 2024-06-01
# 6508 -1.409959  Product_075 2024-07-01
# 6509 -1.409959  Product_075 2024-08-01
#
# [6510 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6519        NaN         NaN          35865.710686  0.0   7687.364933
# 6520        NaN         NaN          33864.759922  0.0   7687.364933
# 6521        NaN         NaN          38148.772823  0.0   7687.364933
# 6522        NaN         NaN          39896.287753  0.0   7687.364933
# 6523        NaN         NaN          32661.382359  0.0   7687.364933
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6519 -0.409213  Product_076 2024-04-01
# 6520 -0.409213  Product_076 2024-05-01
# 6521 -0.409213  Product_076 2024-06-01
# 6522 -0.409213  Product_076 2024-07-01
# 6523 -0.409213  Product_076 2024-08-01
#
# [6524 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6533        NaN         NaN          35106.717144  0.0   4901.691767
# 6534        NaN         NaN          31089.095275  0.0   4901.691767
# 6535        NaN         NaN          30556.597950  0.0   4901.691767
# 6536        NaN         NaN          35447.754382  0.0   4901.691767
# 6537        NaN         NaN          34000.600340  0.0   4901.691767
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6533 -0.264761  Product_077 2024-04-01
# 6534 -0.264761  Product_077 2024-05-01
# 6535 -0.264761  Product_077 2024-06-01
# 6536 -0.264761  Product_077 2024-07-01
# 6537 -0.264761  Product_077 2024-08-01
#
# [6538 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6547        NaN         NaN          35250.046491  0.0   4356.122518
# 6548        NaN         NaN          32112.892628  0.0   4356.122518
# 6549        NaN         NaN          29066.032274  0.0   4356.122518
# 6550        NaN         NaN          34344.693365  0.0   4356.122518
# 6551        NaN         NaN          29268.055831  0.0   4356.122518
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6547  0.009925  Product_078 2024-04-01
# 6548  0.009925  Product_078 2024-05-01
# 6549  0.009925  Product_078 2024-06-01
# 6550  0.009925  Product_078 2024-07-01
# 6551  0.009925  Product_078 2024-08-01
#
# [6552 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6561        NaN         NaN          24054.318417  0.0   4631.120930
# 6562        NaN         NaN          20939.404814  0.0   4631.120930
# 6563        NaN         NaN          27184.770342  0.0   4631.120930
# 6564        NaN         NaN          31807.583946  0.0   4631.120930
# 6565        NaN         NaN          22897.812232  0.0   4631.120930
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6561  0.289637  Product_079 2024-04-01
# 6562  0.289637  Product_079 2024-05-01
# 6563  0.289637  Product_079 2024-06-01
# 6564  0.289637  Product_079 2024-07-01
# 6565  0.289637  Product_079 2024-08-01
#
# [6566 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6575        NaN         NaN          23751.029868  0.0   7759.715945
# 6576        NaN         NaN          21726.162842  0.0   7759.715945
# 6577        NaN         NaN          22838.500943  0.0   7759.715945
# 6578        NaN         NaN          23152.399518  0.0   7759.715945
# 6579        NaN         NaN          19095.628520  0.0   7759.715945
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6575 -0.895914  Product_082 2024-04-01
# 6576 -0.895914  Product_082 2024-05-01
# 6577 -0.895914  Product_082 2024-06-01
# 6578 -0.895914  Product_082 2024-07-01
# 6579 -0.895914  Product_082 2024-08-01
#
# [6580 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6589        NaN         NaN          27022.470602  0.0   5892.158348
# 6590        NaN         NaN          22920.293417  0.0   5892.158348
# 6591        NaN         NaN          28965.149510  0.0   5892.158348
# 6592        NaN         NaN          29338.826262  0.0   5892.158348
# 6593        NaN         NaN          25862.194825  0.0   5892.158348
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6589 -0.051646  Product_083 2024-04-01
# 6590 -0.051646  Product_083 2024-05-01
# 6591 -0.051646  Product_083 2024-06-01
# 6592 -0.051646  Product_083 2024-07-01
# 6593 -0.051646  Product_083 2024-08-01
#
# [6594 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6603        NaN         NaN          32663.655094  0.0   6475.822409
# 6604        NaN         NaN          32328.715432  0.0   6475.822409
# 6605        NaN         NaN          33773.476307  0.0   6475.822409
# 6606        NaN         NaN          42796.399505  0.0   6475.822409
# 6607        NaN         NaN          31854.035166  0.0   6475.822409
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6603 -0.111395  Product_085 2024-04-01
# 6604 -0.111395  Product_085 2024-05-01
# 6605 -0.111395  Product_085 2024-06-01
# 6606 -0.111395  Product_085 2024-07-01
# 6607 -0.111395  Product_085 2024-08-01
#
# [6608 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6617        NaN         NaN          25749.585332  0.0   6498.994882
# 6618        NaN         NaN          27316.605958  0.0   6498.994882
# 6619        NaN         NaN          29612.909828  0.0   6498.994882
# 6620        NaN         NaN          26576.182335  0.0   6498.994882
# 6621        NaN         NaN          22046.064070  0.0   6498.994882
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6617 -1.684543  Product_086 2024-04-01
# 6618 -1.684543  Product_086 2024-05-01
# 6619 -1.684543  Product_086 2024-06-01
# 6620 -1.684543  Product_086 2024-07-01
# 6621 -1.684543  Product_086 2024-08-01
#
# [6622 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6631        NaN         NaN          24994.338499  0.0   5478.469194
# 6632        NaN         NaN          25413.517211  0.0   5478.469194
# 6633        NaN         NaN          26177.259668  0.0   5478.469194
# 6634        NaN         NaN          31954.183151  0.0   5478.469194
# 6635        NaN         NaN          23050.485681  0.0   5478.469194
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6631 -0.247626  Product_087 2024-04-01
# 6632 -0.247626  Product_087 2024-05-01
# 6633 -0.247626  Product_087 2024-06-01
# 6634 -0.247626  Product_087 2024-07-01
# 6635 -0.247626  Product_087 2024-08-01
#
# [6636 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6645        NaN         NaN          21746.950986  0.0   9634.502636
# 6646        NaN         NaN          20149.376941  0.0   9634.502636
# 6647        NaN         NaN          24123.325468  0.0   9634.502636
# 6648        NaN         NaN          26685.269021  0.0   9634.502636
# 6649        NaN         NaN          18428.908222  0.0   9634.502636
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6645 -0.945341  Product_088 2024-04-01
# 6646 -0.945341  Product_088 2024-05-01
# 6647 -0.945341  Product_088 2024-06-01
# 6648 -0.945341  Product_088 2024-07-01
# 6649 -0.945341  Product_088 2024-08-01
#
# [6650 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6659        NaN         NaN          20522.204402  0.0   7733.807393
# 6660        NaN         NaN          22727.409145  0.0   7733.807393
# 6661        NaN         NaN          24558.066179  0.0   7733.807393
# 6662        NaN         NaN          32400.543768  0.0   7733.807393
# 6663        NaN         NaN          21834.769769  0.0   7733.807393
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6659 -1.109008  Product_090 2024-04-01
# 6660 -1.109008  Product_090 2024-05-01
# 6661 -1.109008  Product_090 2024-06-01
# 6662 -1.109008  Product_090 2024-07-01
# 6663 -1.109008  Product_090 2024-08-01
#
# [6664 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6673        NaN         NaN          19230.717999  0.0  12552.496190
# 6674        NaN         NaN          22225.183579  0.0  12552.496190
# 6675        NaN         NaN          22723.260272  0.0  12552.496190
# 6676        NaN         NaN          21747.752220  0.0  12552.496190
# 6677        NaN         NaN          18581.602257  0.0  12552.496190
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6673 -2.661022  Product_091 2024-04-01
# 6674 -2.661022  Product_091 2024-05-01
# 6675 -2.661022  Product_091 2024-06-01
# 6676 -2.661022  Product_091 2024-07-01
# 6677 -2.661022  Product_091 2024-08-01
#
# [6678 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6687        NaN         NaN          22340.719332  0.0   6520.778874
# 6688        NaN         NaN          21884.375213  0.0   6520.778874
# 6689        NaN         NaN          26448.833443  0.0   6520.778874
# 6690        NaN         NaN          26564.587441  0.0   6520.778874
# 6691        NaN         NaN          18243.071733  0.0   6520.778874
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6687 -0.975515  Product_093 2024-04-01
# 6688 -0.975515  Product_093 2024-05-01
# 6689 -0.975515  Product_093 2024-06-01
# 6690 -0.975515  Product_093 2024-07-01
# 6691 -0.975515  Product_093 2024-08-01
#
# [6692 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6701        NaN         NaN          44607.163957  0.0  12038.697544
# 6702        NaN         NaN          39494.443920  0.0  12038.697544
# 6703        NaN         NaN          45542.002931  0.0  12038.697544
# 6704        NaN         NaN          53005.185155  0.0  12038.697544
# 6705        NaN         NaN          47163.641111  0.0  12038.697544
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6701 -1.775735  Product_094 2024-04-01
# 6702 -1.775735  Product_094 2024-05-01
# 6703 -1.775735  Product_094 2024-06-01
# 6704 -1.775735  Product_094 2024-07-01
# 6705 -1.775735  Product_094 2024-08-01
#
# [6706 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6715        NaN         NaN          31690.219230  0.0   6337.297123
# 6716        NaN         NaN          22710.139234  0.0   6337.297123
# 6717        NaN         NaN          27084.297551  0.0   6337.297123
# 6718        NaN         NaN          31469.143192  0.0   6337.297123
# 6719        NaN         NaN          25067.148129  0.0   6337.297123
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6715 -1.055735  Product_095 2024-04-01
# 6716 -1.055735  Product_095 2024-05-01
# 6717 -1.055735  Product_095 2024-06-01
# 6718 -1.055735  Product_095 2024-07-01
# 6719 -1.055735  Product_095 2024-08-01
#
# [6720 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6729        NaN         NaN          24824.093583  0.0   4548.638794
# 6730        NaN         NaN          21673.642843  0.0   4548.638794
# 6731        NaN         NaN          26947.429521  0.0   4548.638794
# 6732        NaN         NaN          29260.457358  0.0   4548.638794
# 6733        NaN         NaN          21750.207947  0.0   4548.638794
#
#       r2_score   product_id order_date
# 0     -0.05509  Product_001 2023-07-01
# 1     -0.05509  Product_001 2023-08-01
# 2     -0.05509  Product_001 2023-09-01
# 3     -0.05509  Product_001 2023-10-01
# 4     -0.05509  Product_001 2023-11-01
# ...        ...          ...        ...
# 6729  -0.33776  Product_096 2024-04-01
# 6730  -0.33776  Product_096 2024-05-01
# 6731  -0.33776  Product_096 2024-06-01
# 6732  -0.33776  Product_096 2024-07-01
# 6733  -0.33776  Product_096 2024-08-01
#
# [6734 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6743        NaN         NaN          29185.228866  0.0   6449.963355
# 6744        NaN         NaN          25754.747842  0.0   6449.963355
# 6745        NaN         NaN          28192.239900  0.0   6449.963355
# 6746        NaN         NaN          29121.483817  0.0   6449.963355
# 6747        NaN         NaN          22754.638815  0.0   6449.963355
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6743 -0.406523  Product_097 2024-04-01
# 6744 -0.406523  Product_097 2024-05-01
# 6745 -0.406523  Product_097 2024-06-01
# 6746 -0.406523  Product_097 2024-07-01
# 6747 -0.406523  Product_097 2024-08-01
#
# [6748 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6757        NaN         NaN          20157.487535  0.0   7999.723248
# 6758        NaN         NaN          18177.424954  0.0   7999.723248
# 6759        NaN         NaN          20904.460577  0.0   7999.723248
# 6760        NaN         NaN          31158.572506  0.0   7999.723248
# 6761        NaN         NaN          17857.370578  0.0   7999.723248
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6757 -3.594857  Product_098 2024-04-01
# 6758 -3.594857  Product_098 2024-05-01
# 6759 -3.594857  Product_098 2024-06-01
# 6760 -3.594857  Product_098 2024-07-01
# 6761 -3.594857  Product_098 2024-08-01
#
# [6762 rows x 8 columns]
#      PRODUCT_ID ORDER_MONTH  test_forecast_orders  rse          rmse  \
# 0           NaN         NaN         118823.028009  0.0  15697.565379
# 1           NaN         NaN         101123.262760  0.0  15697.565379
# 2           NaN         NaN         105282.149996  0.0  15697.565379
# 3           NaN         NaN         117745.845182  0.0  15697.565379
# 4           NaN         NaN         110611.593083  0.0  15697.565379
# ...         ...         ...                   ...  ...           ...
# 6771        NaN         NaN          18561.642690  0.0   8128.208481
# 6772        NaN         NaN          21368.799836  0.0   8128.208481
# 6773        NaN         NaN          24816.242093  0.0   8128.208481
# 6774        NaN         NaN          21318.819139  0.0   8128.208481
# 6775        NaN         NaN          18964.048803  0.0   8128.208481
#
#       r2_score   product_id order_date
# 0    -0.055090  Product_001 2023-07-01
# 1    -0.055090  Product_001 2023-08-01
# 2    -0.055090  Product_001 2023-09-01
# 3    -0.055090  Product_001 2023-10-01
# 4    -0.055090  Product_001 2023-11-01
# ...        ...          ...        ...
# 6771 -2.288506  Product_100 2024-04-01
# 6772 -2.288506  Product_100 2024-05-01
# 6773 -2.288506  Product_100 2024-06-01
# 6774 -2.288506  Product_100 2024-07-01
# 6775 -2.288506  Product_100 2024-08-01
#
# [6776 rows x 8 columns]
