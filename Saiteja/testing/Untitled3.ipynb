# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.9/site-packages (0.14.3)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (23.2)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/conda/lib/python3.9/site-packages (from statsmodels) (2.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# WARNING: You are using pip version 19.3.1; however, version 24.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, r2_score

# %%
from fosforml.model_manager.snowflakesession import get_session
my_session = get_session()
 
table_name = '"MASTER_DATA"'
 
sf_df = my_session.sql("select * from {}".format(table_name))
df = sf_df.to_pandas()

# %%
df
# Out:
#         PRODUCT_CODE  PRODUCT_DESCRIPTION CATEGORY_CODE         CATEGORY  \
# 0        Product_001       X299M Extreme4       Cat_001  MicroATX Boards
# 1        Product_001       X299M Extreme4       Cat_001  MicroATX Boards
# 2        Product_001       X299M Extreme4       Cat_001  MicroATX Boards
# 3        Product_001       X299M Extreme4       Cat_001  MicroATX Boards
# 4        Product_001       X299M Extreme4       Cat_001  MicroATX Boards
# ...              ...                  ...           ...              ...
# 4213390  Product_085  ULTRA QUAD M.2 CARD       Cat_007      Addon Cards
# 4213391  Product_085  ULTRA QUAD M.2 CARD       Cat_007      Addon Cards
# 4213392  Product_085  ULTRA QUAD M.2 CARD       Cat_007      Addon Cards
# 4213393  Product_085  ULTRA QUAD M.2 CARD       Cat_007      Addon Cards
# 4213394  Product_085  ULTRA QUAD M.2 CARD       Cat_007      Addon Cards
#
#          MANUFACTURING_LT  MFG_COST  LABOR_COST  PROFIT_MARGIN CUSTOMER_CODE  \
# 0                       1     55.12       36.74            0.2       Cust_16
# 1                       1     55.12       36.74            0.2       Cust_16
# 2                       1     55.12       36.74            0.2       Cust_16
# 3                       1     55.12       36.74            0.2       Cust_16
# 4                       1     55.12       36.74            0.2       Cust_16
# ...                   ...       ...         ...            ...           ...
# 4213390                 1      0.99        0.66            0.2       Cust_04
# 4213391                 1      0.99        0.66            0.2       Cust_04
# 4213392                 1      0.99        0.66            0.2       Cust_04
# 4213393                 1      0.99        0.66            0.2       Cust_04
# 4213394                 1      0.99        0.66            0.2       Cust_04
#
#           PRODUCT_ID  ...  Fact_Customer_Orders_PRODUCT_ID  ORDER_QTY  \
# 0        Product_001  ...                      Product_001        850
# 1        Product_001  ...                      Product_001        850
# 2        Product_001  ...                      Product_001        850
# 3        Product_001  ...                      Product_001        850
# 4        Product_001  ...                      Product_001        850
# ...              ...  ...                              ...        ...
# 4213390  Product_085  ...                      Product_085        650
# 4213391  Product_085  ...                      Product_085        700
# 4213392  Product_085  ...                      Product_085        700
# 4213393  Product_085  ...                      Product_085        850
# 4213394  Product_085  ...                      Product_085        850
#
#          ORDER_DATE  PART_CODE QPA UOM UNIT_PRICE LEAD_TIME_IN_WEEKS   MOQ  \
# 0        2019-01-02  Part_1204   7  EA       1.30                  7   500
# 1        2019-01-02  Part_0941   2  EA       1.86                  6  1500
# 2        2019-01-02  Part_0138  10  EA       0.52                 12   500
# 3        2019-01-02  Part_1181   5  EA       0.65                  3   500
# 4        2019-01-02  Part_1754   9  EA       1.75                  8  1500
# ...             ...        ...  ..  ..        ...                ...   ...
# 4213390  2024-08-31  Part_0066   3  EA       0.80                  8  1500
# 4213391  2024-08-31  Part_1101   2  EA       1.38                  7   500
# 4213392  2024-08-31  Part_0066   3  EA       0.80                  8  1500
# 4213393  2024-08-31  Part_1101   2  EA       1.38                  7   500
# 4213394  2024-08-31  Part_0066   3  EA       0.80                  8  1500
#
#         PROD_LIFE_CYCLE
# 0            Production
# 1            Production
# 2            Production
# 3            Production
# 4            Production
# ...                 ...
# 4213390      Production
# 4213391      Production
# 4213392      Production
# 4213393      Production
# 4213394      Production
#
# [4213395 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213395 entries, 0 to 4213394
# Data columns (total 30 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   PRODUCT_CODE                     object
#  1   PRODUCT_DESCRIPTION              object
#  2   CATEGORY_CODE                    object
#  3   CATEGORY                         object
#  4   MANUFACTURING_LT                 int8
#  5   MFG_COST                         float64
#  6   LABOR_COST                       float64
#  7   PROFIT_MARGIN                    float64
#  8   CUSTOMER_CODE                    object
#  9   PRODUCT_ID                       object
#  10  Production_Cost                  float64
#  11  Profit                           float64
#  12  Sales                            float64
#  13  SUM_Part_Cost                    float64
#  14  CUSTOMER_NAME                    object
#  15  CITY                             object
#  16  STATE_PROVINCE                   object
#  17  COUNTRY_CODE                     object
#  18  TRANSIT_LT                       int8
#  19  ORDER_ID                         object
#  20  Fact_Customer_Orders_PRODUCT_ID  object
#  21  ORDER_QTY                        int16
#  22  ORDER_DATE                       object
#  23  PART_CODE                        object
#  24  QPA                              int8
#  25  UOM                              object
#  26  UNIT_PRICE                       float64
#  27  LEAD_TIME_IN_WEEKS               int8
#  28  MOQ                              int16
#  29  PROD_LIFE_CYCLE                  object
# dtypes: float64(8), int16(2), int8(4), object(16)
# memory usage: 803.6+ MB
